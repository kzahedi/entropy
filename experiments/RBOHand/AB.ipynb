# %%
using ProgressMeter

# %%
dir = "11b25143-e0b1-49cb-a450-1b682de090fc"
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)

w_indices = "18,19,20,33,34,35,48,49,50,63,64,65,93,94,95"
a_indices = "8,9,10,11"
wbins     = 300
abins     = 100
# Out:
# 100

# %% [markdown]
# ### 1) Preprocessing the files

# %%
function copy_and_convert_hand(path)

    in_dirs  = map(x->"$path/$x/raw", dirs)
    out_dirs = map(x->"$path/$x/analysis", dirs)

    p = Progress(length(in_dirs)*1, 1, "hand.sofastates.csv ...")

    r = collect(1:7:224)
    s = collect(2:7:224)
    t = collect(3:7:224)
    r = vcat(r',s',t')
    r = vec(r)

    for index in 1:length(in_dirs)
        if isfile("$(in_dirs[index])/hand.sofastates.txt")
            a = readcsv("$(in_dirs[index])/hand.sofastates.txt")[2:2:end,:]
            a = map(x->replace(x,"  X= ",""),a)
            m = nothing
            for j = 1:length(a)
                b = a[j]
                c = split(b, " ")
                d = map(x->parse(Float64,x), [d for d in c])
                f = convert(Array{Float64,1},d)'
                if m == nothing
                    m = f[r]'
                else
                    m = vcat(m, f[r]')
                end
            end

            for j = 1:size(m)[1]
                for k = 5:3:size(m)[2]
                    m[j,k] -= m[j,2]
                end
                m[j,2] = 0.0
            end
            writecsv("$(out_dirs[index])/hand.sofastates.csv",m)
        end
        next!(p)
    end
end
   
function copy_and_convert_control(path)
    dirs = readdir(path)
    dirs = filter(x->contains(x,"hand"), dirs)

    in_dirs  = map(x->"$path/$x/raw", dirs)
    out_dirs = map(x->"$path/$x/analysis", dirs)

    p = Progress(length(in_dirs), 1, "control.states.csv ...")

    for i in 1:length(in_dirs)
        if isfile("$(in_dirs[i])/control.states.csv")
            a = readcsv("$(in_dirs[i])/control.states.csv")[2:end-1,:]
            a = map(x->Float64(x),a)
            writecsv("$(out_dirs[i])/control.states.csv",a)
        end
        next!(p)
    end
end

function copy_and_convert_files(path)
    copy_and_convert_hand(path)
    copy_and_convert_control(path)
end
# Out:
# copy_and_convert_files (generic function with 1 method)

# %%
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"

copy_and_convert_files(path)
# Out:
# hand.sofastates.csv ...100% Time: 0:02:57
# control.states.csv ...100% Time: 0:00:12

# %% [markdown]
# ### 2)  Get Min/Max Values

# %%
function write_domains(path)    
    in_dirs      = map(x->"$path/$x/analysis", dirs)
    controlfiles = map(x->"$x/control.states.csv",in_dirs)
    a_domains    = map(x->"$x/A.domains.csv",in_dirs)
    handfiles    = map(x->"$x/hand.sofastates.csv",in_dirs)
    w_domains    = map(x->"$x/W.domains.csv",in_dirs)

    function minmax(in_,out_)
        a = readcsv(in_)
        b = minimum(a,1)
        c = maximum(a,1)
        d = vcat(b,c)
        writecsv(out_, d)
    end

    p = Progress(length(in_dirs), 1, "domain files ...")

    for i = 1:length(in_dirs)
        if isfile(controlfiles[i])
            minmax(controlfiles[i], a_domains[i])
        end
        if isfile(handfiles[i])
            minmax(handfiles[i],w_domains[i])
        end
        next!(p)
    end
end

path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
write_domains(path)
# Out:
# domain files ...100% Time: 0:00:20

# %% [markdown]
# ### 3)  Hand, Controller, Objects, Positions

# %%
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
in_dirs = map(x->"$path/$x/analysis", dirs)

fd = open("Makefile.1","w")
write(fd,"all:\n")
for d in in_dirs
    command = "/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$d\""   
    write(fd,"\t$command\n")
end
close(fd)
run(`make -j 4 -f Makefile.1`)
# Out:
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-10.0_-15.0/analysis"
# MC: 4.50972
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-10.0_-7.5/analysis"
# MC: 4.44556
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-10.0_0.0/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-10.0_15.0/analysis"
# MC: 4.34055
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-10.0_7.5/analysis"
# MC: 4.17183
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-5.0_-15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-5.0_-7.5/analysis"
# MC: 4.40755
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-5.0_0.0/analysis"
# MC: 4.24542
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-5.0_15.0/analysis"
# MC: 4.42559
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_-5.0_7.5/analysis"
# MC: 4.59048
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_0.0_-15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_0.0_-7.5/analysis"
# MC: 4.48001
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_0.0_0.0/analysis"
# MC: 4.40773
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_0.0_15.0/analysis"
# MC: 4.52896
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_0.0_7.5/analysis"
# MC: 4.32059
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_10.0_-15.0/analysis"
# MC: 4.17019
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_10.0_-7.5/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_10.0_0.0/analysis"
# MC: 4.61592
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_10.0_15.0/analysis"
# MC: 4.5636
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_10.0_7.5/analysis"
# MC: 4.30773
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_5.0_-15.0/analysis"
# MC: 4.10977
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_5.0_-7.5/analysis"
# MC: 4.32709
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_5.0_0.0/analysis"
# MC: 4.45175
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_5.0_15.0/analysis"
# MC: 4.39186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-10.0_5.0_7.5/analysis"
# MC: 4.58693
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-10.0_-15.0/analysis"
# MC: 4.35668
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-10.0_-7.5/analysis"
# MC: 4.31157
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-10.0_0.0/analysis"
# MC: 4.06641
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-10.0_15.0/analysis"
# MC: 4.27875
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-10.0_7.5/analysis"
# MC: 4.47809
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-5.0_-15.0/analysis"
# MC: 4.28614
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-5.0_-7.5/analysis"
# MC: 4.30935
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-5.0_0.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-5.0_15.0/analysis"
# MC: 4.36973
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_-5.0_7.5/analysis"
# MC: 4.53443
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_0.0_-15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_0.0_-7.5/analysis"
# MC: 4.27419
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_0.0_0.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_0.0_15.0/analysis"
# MC: 4.59048
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_0.0_7.5/analysis"
# MC: 4.24502
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_10.0_-15.0/analysis"
# MC: 4.21458
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_10.0_-7.5/analysis"
# MC: 4.61592
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_10.0_0.0/analysis"
# MC: 4.48375
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_10.0_15.0/analysis"
# MC: 4.0981
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_10.0_7.5/analysis"
# MC: 4.28614
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_5.0_-15.0/analysis"
# MC: 4.27267
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_5.0_-7.5/analysis"
# MC: 4.2276
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_5.0_0.0/analysis"
# MC: 4.42559
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_5.0_15.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_-5.0_5.0_7.5/analysis"
# MC: 4.30213
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-10.0_-15.0/analysis"
# MC: 4.13448
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-10.0_-7.5/analysis"
# MC: 4.31056
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-10.0_0.0/analysis"
# MC: 4.29296
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-10.0_15.0/analysis"
# MC: 4.36835
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-10.0_7.5/analysis"
# MC: 4.1259
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-5.0_-15.0/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-5.0_-7.5/analysis"
# MC: 4.38067
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-5.0_0.0/analysis"
# MC: 4.47099
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-5.0_15.0/analysis"
# MC: 4.68838
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_-5.0_7.5/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_0.0_-15.0/analysis"
# MC: 4.59259
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_0.0_-7.5/analysis"
# MC: 4.24579
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_0.0_0.0/analysis"
# MC: 4.50708
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_0.0_15.0/analysis"
# MC: 4.56222
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_0.0_7.5/analysis"
# MC: 4.22564
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_10.0_-15.0/analysis"
# MC: 4.52896
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_10.0_-7.5/analysis"
# MC: 4.39516
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_10.0_0.0/analysis"
# MC: 4.3126
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_10.0_15.0/analysis"
# MC: 4.42901
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_10.0_7.5/analysis"
# MC: 4.36643
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_5.0_-15.0/analysis"
# MC: 4.36926
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_5.0_-7.5/analysis"
# MC: 4.35668
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_5.0_0.0/analysis"
# MC: 4.50353
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_5.0_15.0/analysis"
# MC: 4.25023
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_0.0_5.0_7.5/analysis"
# MC: 4.15586
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-10.0_-15.0/analysis"
# MC: 4.24457
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-10.0_-7.5/analysis"
# MC: 4.44303
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-10.0_0.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-10.0_15.0/analysis"
# MC: 4.21517
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-10.0_7.5/analysis"
# MC: 4.3082
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-5.0_-15.0/analysis"
# MC: 4.08438
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-5.0_-7.5/analysis"
# MC: 4.547
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-5.0_0.0/analysis"
# MC: 4.45621
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-5.0_15.0/analysis"
# MC: 4.36304
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_-5.0_7.5/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_0.0_-15.0/analysis"
# MC: 4.35505
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_0.0_-7.5/analysis"
# MC: 4.3435
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_0.0_0.0/analysis"
# MC: 4.5924
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_0.0_15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_0.0_7.5/analysis"
# MC: 4.36498
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_10.0_-15.0/analysis"
# MC: 4.39853
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_10.0_-7.5/analysis"
# MC: 4.40016
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_10.0_0.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_10.0_15.0/analysis"
# MC: 4.59048
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_10.0_7.5/analysis"
# MC: 4.50544
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_5.0_-15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_5.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_5.0_0.0/analysis"
# MC: 4.61592
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_5.0_15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_10.0_5.0_7.5/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-10.0_-15.0/analysis"
# MC: 4.31867
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-10.0_-7.5/analysis"
# MC: 4.33971
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-10.0_0.0/analysis"
# MC: 4.59048
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-10.0_15.0/analysis"
# MC: 4.35963
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-10.0_7.5/analysis"
# MC: 4.35879
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-5.0_-15.0/analysis"
# MC: 4.38758
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-5.0_-7.5/analysis"
# MC: 4.53059
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-5.0_0.0/analysis"
# MC: 4.29041
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-5.0_15.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_-5.0_7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_0.0_-15.0/analysis"
# MC: 4.2607
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_0.0_-7.5/analysis"
# MC: 4.47665
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_0.0_0.0/analysis"
# MC: 4.31748
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_0.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_0.0_7.5/analysis"
# MC: 4.44911
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_10.0_-15.0/analysis"
# MC: 4.20883
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_10.0_-7.5/analysis"
# MC: 4.23436
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_10.0_0.0/analysis"
# MC: 4.46715
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_10.0_15.0/analysis"
# MC: 4.05799
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_10.0_7.5/analysis"
# MC: 4.31307
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_5.0_-15.0/analysis"
# MC: 4.50708
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_5.0_-7.5/analysis"
# MC: 4.43653
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_5.0_0.0/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_5.0_15.0/analysis"
# MC: 4.54345
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectboxB_5.0_5.0_7.5/analysis"
# MC: 4.58693
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-10.0_-15.0/analysis"
# MC: 3.84305
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-10.0_-7.5/analysis"
# MC: 4.61592
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-10.0_0.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-10.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-10.0_7.5/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-5.0_-15.0/analysis"
# MC: 4.53324
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-5.0_-7.5/analysis"
# MC: 4.64845
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-5.0_0.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-5.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_-5.0_7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_0.0_-15.0/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_0.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_0.0_0.0/analysis"
# MC: 4.65392
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_0.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_0.0_7.5/analysis"
# MC: 4.44027
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_10.0_-15.0/analysis"
# MC: 4.6449
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_10.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_10.0_0.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_10.0_15.0/analysis"
# MC: 4.03349
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_10.0_7.5/analysis"
# MC: 4.5615
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_5.0_-15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_5.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_5.0_0.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_5.0_15.0/analysis"
# MC: 3.61008
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-10.0_5.0_7.5/analysis"
# MC: 4.55795
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-10.0_-15.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-10.0_-7.5/analysis"
# MC: 4.42223
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-10.0_0.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-10.0_15.0/analysis"
# MC: 4.65939
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-10.0_7.5/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-5.0_-15.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-5.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-5.0_0.0/analysis"
# MC: 4.42559
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-5.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_-5.0_7.5/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_0.0_-15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_0.0_-7.5/analysis"
# MC: 4.547
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_0.0_0.0/analysis"
# MC: 4.58693
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_0.0_15.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_0.0_7.5/analysis"
# MC: 4.65939
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_10.0_-15.0/analysis"
# MC: 4.57599
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller0-objectbox_-5.0_10.0_-7.5/analysis"
# MC: 4.65939
# ...
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_0.0_5.0_-15.0/analysis"
# MC: 3.73735
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_0.0_5.0_-7.5/analysis"
# MC: 4.0967
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_0.0_5.0_0.0/analysis"
# MC: 3.96247
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_0.0_5.0_15.0/analysis"
# MC: 4.19058
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_0.0_5.0_7.5/analysis"
# MC: 4.10795
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-10.0_-15.0/analysis"
# MC: 4.66295
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-10.0_-7.5/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-10.0_0.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-10.0_15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-10.0_7.5/analysis"
# MC: 4.53324
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-5.0_-15.0/analysis"
# MC: 4.6974
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-5.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-5.0_0.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-5.0_15.0/analysis"
# MC: 4.59048
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_-5.0_7.5/analysis"
# MC: 4.2607
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_0.0_-15.0/analysis"
# MC: 4.58693
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_0.0_-7.5/analysis"
# MC: 4.6974
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_0.0_0.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_0.0_15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_0.0_7.5/analysis"
# MC: 4.67744
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_10.0_-15.0/analysis"
# MC: 4.39679
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_10.0_-7.5/analysis"
# MC: 4.57599
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_10.0_0.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_10.0_15.0/analysis"
# MC: 4.5615
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_10.0_7.5/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_5.0_-15.0/analysis"
# MC: 4.61592
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_5.0_-7.5/analysis"
# MC: 4.71737
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_5.0_0.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_5.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_10.0_5.0_7.5/analysis"
# MC: 4.5078
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-10.0_-15.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-10.0_-7.5/analysis"
# MC: 4.30556
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-10.0_0.0/analysis"
# MC: 4.11422
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-10.0_15.0/analysis"
# MC: 4.14254
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-10.0_7.5/analysis"
# MC: 3.61886
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-5.0_-15.0/analysis"
# MC: 4.67744
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-5.0_-7.5/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-5.0_0.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-5.0_15.0/analysis"
# MC: 4.64845
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_-5.0_7.5/analysis"
# MC: 4.65939
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_0.0_-15.0/analysis"
# MC: 4.5636
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_0.0_-7.5/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_0.0_0.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_0.0_15.0/analysis"
# MC: 4.71737
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_0.0_7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_10.0_-15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_10.0_-7.5/analysis"
# MC: 4.5615
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_10.0_0.0/analysis"
# MC: 4.61947
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_10.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_10.0_7.5/analysis"
# MC: 4.61592
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_5.0_-15.0/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_5.0_-7.5/analysis"
# MC: 4.73186
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_5.0_0.0/analysis"
# MC: 4.67389
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_5.0_15.0/analysis"
# MC: 4.70287
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//hand0_0-controller2-objectsphere_5.0_5.0_7.5/analysis"
# MC: 4.67389

# %% [markdown]
# ### 4) Hand, Controller, Objects, Average over positions

# %%
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
parents = map(x->replace(x, r"^(.+object\w+)_.+$", s"\g<1>"),dirs)
parents = unique(parents)

for d in parents
    mkpath("$path/combined/object_position/$d/analysis")
end

pg = Progress(length(parents), 1, "combine hand.sofastates.csv and control.states.csv ...")

for p in parents
    ds = filter(x->contains(x,"$(p)_"),dirs)
    hand = nothing
    control = nothing
    
    for a in ds
        pp = "$path/$a/analysis/hand.sofastates.csv"
        if isfile(pp)
            h = readcsv(pp)
            if hand == nothing
                hand = h
            else
                hand = vcat(hand,h)
            end
        else
            println(">  missing $pp")
        end

        pp = "$path/$a/analysis/control.states.csv"
        if isfile(pp)
            c = readcsv(pp)
            if control == nothing
                control = c
            else
                control = vcat(control,c)
            end
        else
            println(">  missing $pp")
        end
    end
    if hand != nothing
        writecsv("$path/combined/object_position/$p/analysis/hand.sofastates.csv",hand)
    end
    if control != nothing
        writecsv("$path/combined/object_position/$p/analysis/control.states.csv", control)
    end
    next!(pg)
end
# Out:
# combine hand.sofastates.csv and control.states.csv ...100% Time: 0:01:03

# %%
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
write_domains("$path/combined/object_position/")

# %%
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
dirs = readdir("$path/combined/object_position")
dirs = filter(x->contains(x,"hand"),dirs)
parents = map(x->replace(x, r"^(.+object\w+)_.+$", s"\g<1>"),dirs)
parents = unique(parents)

fd = open("Makefile.2","w")
write(fd,"all:\n")
for p in parents
    command = "/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$path/combined/object_position/$p/analysis\""   
    write(fd,"\t$command\n")
end
close(fd)
run(`make -j 4 -f Makefile.2`)
# Out:
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectbox/analysis"
# MC: 11.1542
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectboxB/analysis"
# MC: 10.7411
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectcylinder/analysis"
# MC: 10.8074
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectcylinderB/analysis"
# MC: 11.0477
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectegg/analysis"
# MC: 10.7209
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objecteggB/analysis"
# MC: 10.6384
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectsphere/analysis"
# MC: 10.3622
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller0-objectsphereB/analysis"
# MC: 10.6189
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectbox/analysis"
# MC: 11.1111
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectboxB/analysis"
# MC: 10.6633
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectcylinder/analysis"
# MC: 10.8335
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectcylinderB/analysis"
# MC: 11.0971
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectegg/analysis"
# MC: 10.7844
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objecteggB/analysis"
# MC: 10.5821
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectsphere/analysis"
# MC: 10.539
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller1-objectsphereB/analysis"
# MC: 10.4998
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectbox/analysis"
# MC: 11.1204
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectboxB/analysis"
# MC: 10.6392
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectcylinder/analysis"
# MC: 10.6143
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectcylinderB/analysis"
# MC: 11.0434
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectegg/analysis"
# MC: 10.0126
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objecteggB/analysis"
# MC: 10.5076
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectsphere/analysis"
# MC: 9.80219
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position/hand0_0-controller2-objectsphereB/analysis"
# MC: 10.5019

# %% [markdown]
# ### 5) Hand, Controller, Avg over Objects, Position = 0.0, 0.0, 0.0

# %%
path = "/Users/zahedi/Dropbox/Raphael\ -\ Keyan/$dir/"
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
dirs = filter(x->contains(x,"_0.0_0.0_0.0"), dirs)

parents = map(x->replace(x, r"^(.+)-object\w+_0.0_0.0_0.0", s"\g<1>"),dirs)
parents = unique(parents)

for d in parents
    mkpath("$path/combined/object_position_0/$d/analysis")
end

for p in parents
    println(p)
    ds = filter(x->contains(x,"$(p)"),dirs)
    hand = nothing
    control = nothing
    
    for a in ds
        pp = "$path/$a/analysis/hand.sofastates.csv"
        #println(pp)
        #println(a)
        if isfile(pp)
            h = readcsv(pp)
            if hand == nothing
                hand = h
            else
                hand = vcat(hand,h)
            end
        else
            println(">  missing $pp")
        end

        pp = "$path/$a/analysis/control.states.csv"
        if isfile(pp)
            c = readcsv(pp)
            if control == nothing
                control = c
            else
                control = vcat(control,c)
            end
        else
            println(">  missing $pp")
        end
    end
    if hand != nothing
        writecsv("$path/combined/object_position_0/$p/analysis/hand.sofastates.csv",hand)
    end
    if control != nothing
        writecsv("$path/combined/object_position_0/$p/analysis/control.states.csv", control)
    end
    next!(pg)
end

write_domains("$path/combined/object_position_0/")

dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
dirs = filter(x->contains(x,"_0.0_0.0_0.0"), dirs)

parents = map(x->replace(x, r"^(.+)-object\w+_0.0_0.0_0.0", s"\g<1>"),dirs)
parents = unique(parents)

fd = open("Makefile.3","w")
write(fd,"all:\n")
for p in parents
    command = "/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$path/combined/object_position_0/$p/analysis\""   
    write(fd,"\t$command\n")
end
close(fd)
run(`make -j 4 -f Makefile.3`)
# Out:
# hand0_0-controller0
# hand0_0-controller1
# hand0_0-controller2
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position_0/hand0_0-controller0/analysis"
# Assertion failed: (row < _rows), function operator(), file /Users/zahedi/projects/entropy/src/entropy++/Container.h, line 232.
# make: *** [all] Abort trap: 6
# LoadError: failed process: Process(`make -j 4 -f Makefile.3`, ProcessExited(2)) [2]
# while loading In[11], in expression starting on line 71
#
#  in run at /Applications/Julia.app/Contents/Resources/julia/lib/julia/sys.dylib

# %% [markdown]
# ### 6) Hand, Controller, Avg over Objects, Avg Position

# %%
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)

parents = map(x->replace(x, r"^(.+)-object.+", s"\g<1>"),dirs)
parents = unique(parents)

for d in parents
    mkpath("$path/combined/hand_control/$d/analysis")
end

for p in parents
    println(p)
    ds = filter(x->contains(x,"$(p)"),dirs)
    hand = nothing
    control = nothing
    
    for a in ds
        pp = "$path/$a/analysis/hand.sofastates.csv"
        #println(pp)
        #println(a)
        if isfile(pp)
            h = readcsv(pp)
            if hand == nothing
                hand = h
            else
                hand = vcat(hand,h)
            end
        else
            println(">  missing $pp")
        end

        pp = "$path/$a/analysis/control.states.csv"
        if isfile(pp)
            c = readcsv(pp)
            if control == nothing
                control = c
            else
                control = vcat(control,c)
            end
        else
            println(">  missing $pp")
        end
    end
    if hand != nothing
        writecsv("$path/combined/hand_control/$p/analysis/hand.sofastates.csv",hand)
    end
    if control != nothing
        writecsv("$path/combined/hand_control/$p/analysis/control.states.csv", control)
    end
    next!(pg)
end

write_domains("$path/combined/hand_control/")

dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)

parents = map(x->replace(x, r"^(.+)-object.+", s"\g<1>"),dirs)
parents = unique(parents)

fd = open("Makefile.4","w")
write(fd,"all:\n")
for p in parents
    command = "/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$path/combined/hand_control/$p/analysis\""   
    write(fd,"\t$command\n")
end
close(fd)
run(`make -j 4 -f Makefile.4`)
# Out:
# hand0_0-controller0
# hand0_0-controller1
# hand0_0-controller2
# /Users/zahedi/projects/builds/entropy-build/bin/rbo_mc -wi 18,19,20,33,34,35,48,49,50,63,64,65,93,94,95 -ai 8,9,10,11 -wbins 300 -abins 100 -d "/Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/hand_control/hand0_0-controller0/analysis"
# Assertion failed: (row < _rows), function operator(), file /Users/zahedi/projects/entropy/src/entropy++/Container.h, line 232.
# make: *** [all] Abort trap: 6
# LoadError: failed process: Process(`make -j 4 -f Makefile.4`, ProcessExited(2)) [2]
# while loading In[17], in expression starting on line 68
#
#  in run at /Applications/Julia.app/Contents/Resources/julia/lib/julia/sys.dylib

# %% [markdown]
# ### Auswertung

# %%
dirs = readdir("$path/combined/hand_control")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/combined/hand_control/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/combined/hand_control/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
# Out:
# LoadError: SystemError: opening file /Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/hand_control/hand0_0-controller0/analysis/mc_w-averaged_300_100.txt: No such file or directory
# while loading In[18], in expression starting on line 5
#
#  in open at /Applications/Julia.app/Contents/Resources/julia/lib/julia/sys.dylib (repeats 2 times)
#  in readdlm_auto at datafmt.jl:45
#  in readdlm at datafmt.jl:39
#  in readdlm at datafmt.jl:37
#  in readcsv at datafmt.jl:524
#  in anonymous at In[18]:5
#  in map at /Applications/Julia.app/Contents/Resources/julia/lib/julia/sys.dylib

# %%
dirs = readdir("$path/combined/object_position")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/combined/object_position/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/combined/object_position/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)

# %%
dirs = readdir("$path/combined/object_position_0")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/combined/object_position_0/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/combined/object_position_0/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
# Out:
# LoadError: SystemError: opening file /Users/zahedi/Dropbox/Raphael - Keyan/11b25143-e0b1-49cb-a450-1b682de090fc//combined/object_position_0/hand0_0-controller0/analysis/mc_w-averaged_300_100.txt: No such file or directory
# while loading In[20], in expression starting on line 5
#
#  in open at /Applications/Julia.app/Contents/Resources/julia/lib/julia/sys.dylib (repeats 2 times)
#  in readdlm_auto at datafmt.jl:45
#  in readdlm at datafmt.jl:39
#  in readdlm at datafmt.jl:37
#  in readcsv at datafmt.jl:524
#  in anonymous at In[20]:5
#  in map at /Applications/Julia.app/Contents/Resources/julia/lib/julia/sys.dylib

# %%
dirs = readdir("$path")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
