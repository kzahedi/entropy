# %%
using ProgressMeter

# %%
function copy_and_convert_hand(path)

    in_dirs  = map(x->"$path/$x/raw", dirs)
    out_dirs = map(x->"$path/$x/analysis", dirs)

    p = Progress(length(in_dirs)*1, 1, "hand.sofastates.csv ...")

    r = collect(1:7:224)
    s = collect(2:7:224)
    t = collect(3:7:224)
    r = vcat(r',s',t')
    r = vec(r)

    for index in 1:length(in_dirs)
        if isfile("$(in_dirs[index])/hand.sofastates.txt")
            a = readcsv("$(in_dirs[index])/hand.sofastates.txt")[2:2:end,:]
            a = map(x->replace(x,"  X= ",""),a)
            m = nothing
            for j = 1:length(a)
                b = a[j]
                c = split(b, " ")
                d = map(x->parse(Float64,x), [d for d in c])
                f = convert(Array{Float64,1},d)'
                if m == nothing
                    m = f[r]'
                else
                    m = vcat(m, f[r]')
                end
            end

            for j = 1:size(m)[1]
                for k = 5:3:size(m)[2]
                    m[j,k] -= m[j,2]
                end
                m[j,2] = 0.0
            end
            writecsv("$(out_dirs[index])/hand.sofastates.csv",m)
        end
        next!(p)
    end
end
   
function copy_and_convert_control(path)
    dirs = readdir(path)
    dirs = filter(x->contains(x,"hand"), dirs)

    in_dirs  = map(x->"$path/$x/raw", dirs)
    out_dirs = map(x->"$path/$x/analysis", dirs)

    p = Progress(length(in_dirs), 1, "control.states.csv ...")

    for i in 1:length(in_dirs)
        if isfile("$(in_dirs[i])/control.states.csv")
            a = readcsv("$(in_dirs[i])/control.states.csv")[2:end-1,:]
            a = map(x->Float64(x),a)
            writecsv("$(out_dirs[i])/control.states.csv",a)
        end
        next!(p)
    end
end

function copy_and_convert_files(path)
    copy_and_convert_hand(path)
    copy_and_convert_control(path)
end

function write_domains(path)
    
    dirs = readdir(path)
    dirs = filter(x->contains(x,"hand"), dirs)
    
    in_dirs      = map(x->"$path/$x/analysis", dirs)
    controlfiles = map(x->"$x/control.states.csv",in_dirs)
    a_domains    = map(x->"$x/A.domains.csv",in_dirs)
    handfiles    = map(x->"$x/hand.sofastates.csv",in_dirs)
    w_domains    = map(x->"$x/W.domains.csv",in_dirs)

#     println("In dirs:")
#     for d in in_dirs
#         println("  $d")
#     end

#     println("Ctrl files:")
#     for d in controlfiles
#         println("  $d")
#     end

#     println("A domains:")
#     for d in a_domains
#         println("  $d")
#     end

#     println("W domains:")
#     for d in w_domains
#         println("  $d")
#     end

#     println("Hand domains:")
#     for d in handfiles
#         println("  $d")
#     end

    
    function minmax(in_,out_)
        a = readcsv(in_)
        b = minimum(a,1)
        c = maximum(a,1)
        d = vcat(b,c)
        writecsv(out_, d)
    end

    p = Progress(length(in_dirs), 1, "domain files ...")

    for i = 1:length(in_dirs)
        if isfile(controlfiles[i])
            minmax(controlfiles[i], a_domains[i])
        end
        if isfile(handfiles[i])
            minmax(handfiles[i],w_domains[i])
        end
        next!(p)
    end
end
# Out:
# write_domains (generic function with 1 method)

# %%
function do_it()
    copy_and_convert_files(path)
    write_domains(path)
    
    dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
in_dirs = map(x->"$path/$x/analysis", dirs)

fd = open("Makefile.1","w")
write(fd,"all:\n\n")
index = 0
for d in in_dirs
    command = "all: b$index\nb$index:\n\t@/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc --silent -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$d\""   
    write(fd,"$command\n")
    index = index + 1
end
close(fd)
run(`make -j 4 -f Makefile.1`)
    
    parents = map(x->replace(x, r"^(.+object\w+)_.+$", s"\g<1>"),dirs)
parents = unique(parents)

for d in parents
    mkpath("$path/combined/object_position/$d/analysis")
end

pg = Progress(length(parents), 1, "combine hand.sofastates.csv and control.states.csv ...")

for p in parents
    ds = filter(x->contains(x,"$(p)_"),dirs)
    hand = nothing
    control = nothing
    
    for a in ds
        pp = "$path/$a/analysis/hand.sofastates.csv"
        if isfile(pp)
            h = readcsv(pp)
            if hand == nothing
                hand = h
            else
                hand = vcat(hand,h)
            end
        else
            println(">  missing $pp")
        end

        pp = "$path/$a/analysis/control.states.csv"
        if isfile(pp)
            c = readcsv(pp)
            if control == nothing
                control = c
            else
                control = vcat(control,c)
            end
        else
            println(">  missing $pp")
        end
    end
    if hand != nothing
        writecsv("$path/combined/object_position/$p/analysis/hand.sofastates.csv",hand)
    end
    if control != nothing
        writecsv("$path/combined/object_position/$p/analysis/control.states.csv", control)
    end
    next!(pg)
end
    
    write_domains("$path/combined/object_position/")
    
    parents = map(x->replace(x, r"^(.+object\w+)_.+$", s"\g<1>"),dirs)
parents = unique(parents)

fd = open("Makefile.2","w")
write(fd,"all:\n\n")
index = 0
for p in parents
    if isdir("$path/combined/object_position/$p/analysis") == true
        command = "all: b$index\nb$index:\n\t@/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc --silent -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$path/combined/object_position/$p/analysis\""   
        write(fd,"$command\n")
        index = index + 1
    end
end
close(fd)
run(`make -j 4 -f Makefile.2`)
    
    dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
dirs = filter(x->contains(x,"_0.0_0.0_0.0"), dirs)

parents = map(x->replace(x, r"^(.+)-object\w+_0.0_0.0_0.0", s"\g<1>"),dirs)
parents = unique(parents)

for d in parents
    mkpath("$path/combined/object_position_0/$d/analysis")
end

pg = Progress(length(parents), 1, "combine hand.sofastates.csv and control.states.csv ...")

for p in parents
    ds = filter(x->contains(x,"$(p)"),dirs)
    hand = nothing
    control = nothing
    
    for a in ds
        pp = "$path/$a/analysis/hand.sofastates.csv"
        #println(pp)
        #println(a)
        if isfile(pp)
            h = readcsv(pp)
            if hand == nothing
                hand = h
            else
                hand = vcat(hand,h)
            end
        else
            println(">  missing $pp")
        end

        pp = "$path/$a/analysis/control.states.csv"
        if isfile(pp)
            c = readcsv(pp)
            if control == nothing
                control = c
            else
                control = vcat(control,c)
            end
        else
            println(">  missing $pp")
        end
    end
    if hand != nothing
        writecsv("$path/combined/object_position_0/$p/analysis/hand.sofastates.csv",hand)
    end
    if control != nothing
        writecsv("$path/combined/object_position_0/$p/analysis/control.states.csv", control)
    end
    next!(pg)
end

write_domains("$path/combined/object_position_0/")

dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
dirs = filter(x->contains(x,"_0.0_0.0_0.0"), dirs)

parents = map(x->replace(x, r"^(.+)-object\w+_0.0_0.0_0.0", s"\g<1>"),dirs)
parents = unique(parents)

fd = open("Makefile.3","w")
write(fd,"all:\n\n")
index = 0
for p in parents
    command = "all: b$index\nb$index:\n\t@/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc --silent -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$path/combined/object_position_0/$p/analysis\""   
    write(fd,"$command\n")
    index = index + 1
end
close(fd)
run(`make -j 4 -f Makefile.3`)
    
    
    dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)

parents = map(x->replace(x, r"^(.+)-object.+", s"\g<1>"),dirs)
parents = unique(parents)

for d in parents
    mkpath("$path/combined/hand_control/$d/analysis")
end

for p in parents
    println(p)
    ds = filter(x->contains(x,"$(p)"),dirs)
    hand = nothing
    control = nothing
    
    for a in ds
        pp = "$path/$a/analysis/hand.sofastates.csv"
        #println(pp)
        #println(a)
        if isfile(pp)
            h = readcsv(pp)
            if hand == nothing
                hand = h
            else
                hand = vcat(hand,h)
            end
        else
            println(">  missing $pp")
        end

        pp = "$path/$a/analysis/control.states.csv"
        if isfile(pp)
            c = readcsv(pp)
            if control == nothing
                control = c
            else
                control = vcat(control,c)
            end
        else
            println(">  missing $pp")
        end
    end
    if hand != nothing
        writecsv("$path/combined/hand_control/$p/analysis/hand.sofastates.csv",hand)
    end
    if control != nothing
        writecsv("$path/combined/hand_control/$p/analysis/control.states.csv", control)
    end
end

write_domains("$path/combined/hand_control/")

dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)

parents = map(x->replace(x, r"^(.+)-object.+", s"\g<1>"),dirs)
parents = unique(parents)

fd = open("Makefile.4","w")
write(fd,"all:\n\n")
index = 0
for p in parents
        command = "all: b$index\nb$index:\n\t@/Users/zahedi/projects/builds/entropy-build/bin/rbo_mc --silent -wi $(w_indices) -ai $(a_indices) -wbins $wbins -abins $abins -d \"$path/combined/hand_control/$p/analysis\""   
    write(fd,"$command\n")
    index = index + 1
end
close(fd)
run(`make -j 4 -f Makefile.4`)
    
    dirs = readdir("$path/combined/hand_control")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/combined/hand_control/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/combined/hand_control/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
    
    dirs = readdir("$path/combined/object_position")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/combined/object_position/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/combined/object_position/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
    
    
    
    dirs = readdir("$path/combined/object_position_0")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/combined/object_position_0/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/combined/object_position_0/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
    
    dirs = readdir("$path")
in_dirs = filter(x->contains(x,"hand"), dirs)

mc_files = map(x->"$path/$x/analysis/mc_w-averaged_$(wbins)_$(abins).txt", in_dirs)
values   = map(x->readcsv(x)[1],mc_files)
fd = open("$path/results_mc_w-averaged_$(wbins)_$(abins).txt","w")
for i = 1:length(in_dirs)
    write(fd, "$(in_dirs[i]),$(values[i])\n")
end
close(fd)
end
# Out:
# do_it (generic function with 1 method)

# %%
parent = "/Users/zahedi/projects/TU.Berlin/experiments/new/experiment1/"
w_indices = "18,19,20,33,34,35,48,49,50,63,64,65,93,94,95"
a_indices = "8,9,10,11"
wbins     = 500
abins     = 100

experiment = "rbohand2"
path = "$parent/$experiment"
println("####################################")
println("## $experiment")
println("####################################")
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
do_it()

experiment = "rbohand2-prescriptive"
path = "$parent/$experiment"
println("####################################")
println("## $experiment")
println("####################################")
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
do_it()

experiment = "rbohand3"
path = "$parent/$experiment"
println("####################################")
println("## $experiment")
println("####################################")
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
do_it()

experiment = "rbohand3-prescriptive"
path = "$parent/$experiment"
println("####################################")
println("## $experiment")
println("####################################")
dirs = readdir(path)
dirs = filter(x->contains(x,"hand"), dirs)
do_it()
# Out:
# ####################################
# ## rbohand2
# ####################################
# hand.sofastates.csv ...100% Time: 0:02:51
# control.states.csv ...100% Time: 0:00:09
# domain files ...100% Time: 0:01:07
# combine hand.sofastates.csv and control.states.csv ...100% Time: 0:01:07
# domain files ...100% Time: 0:00:20
# hand0_0-controller0
# hand0_0-controller1
# hand0_0-controller2
# domain files ...100% Time: 0:00:22
# ####################################
# ## rbohand2-prescriptive
# ####################################
# hand.sofastates.csv ...100% Time: 0:00:02
# hand0_0-controller0
# hand0_0-controller1
# hand0_0-controller2
# ####################################
# ## rbohand3
# ####################################
# hand.sofastates.csv ...100% Time: 0:03:16
# control.states.csv ...100% Time: 0:00:56
# domain files ...100% Time: 0:01:36
# combine hand.sofastates.csv and control.states.csv ...100% Time: 0:01:06
# domain files ...100% Time: 0:00:17
# hand0_0-controller0
# hand0_0-controller1
# hand0_0-controller2
# domain files ...100% Time: 0:00:20
# ####################################
# ## rbohand3-prescriptive
# ####################################
# hand.sofastates.csv ...100% Time: 0:00:02
# hand0_0-controller0
# hand0_0-controller1
# hand0_0-controller2
